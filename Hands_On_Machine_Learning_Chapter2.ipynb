# %% [markdown]
# <a href="https://colab.research.google.com/github/VarunDevGroup/Machine_Learning_HadnsOn/blob/main/Hands_On_Machine_Learning_Chapter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Chapter 2 – End-to-end Machine Learning project**

# %% [markdown]
# **Chapter 2 – End-to-end Machine Learning project**

# %% [markdown]
# **Import the Python and check whether the Pythom version is >= 3.7**

# %%
import sys

assert sys.version_info >= (3, 7)

# %% [markdown]
# **Import the Scikit-Learn package >=1.0.1**

# %%
from packaging import version
import sklearn

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")
